# %% [markdown]
# # SESSION 5 - Applying Generative Models in Industry

# %% [markdown]
# ### 1.
# **Use ChatGPT to summarize a 3-paragraph news article about IPL cricket into a single short paragraph, then copy both the original and summary into a file called `ipl_summary.txt`.**
#
# ---
# *Completed! The file `ipl_summary.txt` has been created in this folder containing both the original 3-paragraph article and the AI-generated summary.*

# %% [markdown]
# ### 2.
# **Create a simple Q&A chatbot for Zomato-style restaurant info using any language or platform you know (Python, JavaScript, etc.): given a restaurant name and cuisine, return a canned response like 'Yes, Pizza Palace serves Italian cuisine.'**

# %%
def restaurant_chatbot(restaurant_name, cuisine):
    # A simple canned response generator for a restaurant app
    return f"Yes, {restaurant_name} serves delicious {cuisine} cuisine!"

# Let's test the chatbot
print(restaurant_chatbot("Pizza Palace", "Italian"))
print(restaurant_chatbot("Honest", "Pav Bhaji"))
print(restaurant_chatbot("Gopi Dining Hall", "Gujarati Thali"))
# Out:
# Yes, Pizza Palace serves delicious Italian cuisine!
# Yes, Honest serves delicious Pav Bhaji cuisine!
# Yes, Gopi Dining Hall serves delicious Gujarati Thali cuisine!

# %% [markdown]
# ### 3.
# **Generate an original food dish image using DALL·E (or Bing Image Creator) with a prompt like 'A futuristic Gujarati thali with neon colors', then save and submit the image file.**
#
# ---
# **Saved Image (`futuristic_gujarati_thali.jpg`):**
# <img src="futuristic_gujarati_thali.jpg" width="500"/>
#
# *Prompt Used: "A highly futuristic Gujarati thali glowing with vibrant neon colors, sci-fi cyberpunk aesthetic, beautifully plated traditional food, highly detailed, 8k resolution"*

# %% [markdown]
# ### 4.
# **Use GitHub Copilot or ChatGPT to help you write a function that takes a list of song names and returns only those that start with the letter 'S', like a Spotify playlist filter. Constraint: You must show the prompt you used and the code Copilot or ChatGPT generated.**
#
# ---
# **My Prompt to ChatGPT:**
# > Write a Python function that takes a list of song names and returns a new list containing only the songs that start with the letter 'S'.
#
# **ChatGPT's Generated Code:**

# %%
def filter_songs_by_s(song_list):
    # Use a list comprehension to filter songs starting with 'S' or 's'
    return [song for song in song_list if song.lower().startswith('s')]

# Example usage generated by ChatGPT
spotify_playlist = ["Shape of You", "Blinding Lights", "Starboy", "Levitating", "Smells Like Teen Spirit"]
s_songs = filter_songs_by_s(spotify_playlist)
print("Filtered Playlist:", s_songs)
# Out:
# Filtered Playlist: ['Shape of You', 'Starboy', 'Smells Like Teen Spirit']

# %% [markdown]
# ### 5.
# **List two production challenges companies face when using generative AI models for chatbots in apps like BookMyShow or Myntra, and suggest one solution for each challenge.**
#
# ---
# 1. **Challenge 1: Hallucinations (Making up facts).** An AI chatbot for Myntra might confidently tell a customer that an out-of-stock dress is currently available in their size, or invent a fake return policy, leading to extreme customer frustration and lost trust.
#    * **Solution:** Implement **Retrieval-Augmented Generation (RAG)**. Instead of letting the AI guess, force the chatbot to only generate answers based on a strict, real-time database of the actual store inventory and official policy documents.
#
# 2. **Challenge 2: High Latency & Compute Costs.** Running massive GenAI models for thousands of simultaneous BookMyShow customers asking simple questions (e.g., 'What time is the movie?') is incredibly expensive and slow compared to traditional bots.
#    * **Solution:** Use **Hybrid Routing**. Put a cheap, fast traditional ML intent-classifier in front of the GenAI. If the question is simple, route it to a fast traditional database lookup. Only route complex, highly conversational queries to the expensive GenAI model.
